# %%
#installing selenium
pip install selenium
pip install pymongo

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd
import re
from pymongo import MongoClient
import config

# Now you can access the MongoDB connection URL from the config module
mongo_url = config.MONGO_URL

# creating a chrome webdriver to run automation
driver = webdriver.Chrome()

# going to the link
driver.get("https://www.nike.com/ie/w/mens-shoes-nik1zy7ok")


# extracting the link of all the shoes from the product page and stroring it in a list
shoe_ele = driver.find_elements(
    By.CSS_SELECTOR, '[data-testid="product-card__link-overlay"]')

all_shoe_links = []

for i in range(len(shoe_ele)):
    link = shoe_ele[i].get_attribute("href")
    print(link)
    all_shoe_links.append(link)


# creating an empty list to store the values
product_title_list = []
product_category_list = []
product_price_list = []
product_description_list = []
review_count_list = []
product_rating_list = []

for i in range(len(all_shoe_links)):
    driver.get(all_shoe_links[i])
    time.sleep(3)

    # product title
    product_title = driver.find_elements(
        By.CSS_SELECTOR, '[data-test="product-title"]')[1].text
    product_title_list.append(product_title)
    print(product_title)

    # product category
    product_category = driver.find_elements(
        By.CSS_SELECTOR, '[data-test="product-sub-title"]')[1].text
    product_category_list.append(product_category)
    print(product_category)

    # product_price
    product_price = driver.find_elements(
        By.CSS_SELECTOR, '[data-test="product-price"]')[1].text
    product_price_list.append(product_price)
    print(product_price)

    # product_description
    product_description = driver.find_element(
        By.CSS_SELECTOR, '[class="description-preview body-2 css-1pbvugb"]').text
    product_description_list.append(product_description)
    print(product_description)

    # review_count
    review_count = driver.find_elements(
        By.CSS_SELECTOR, '[class="headline-4"]')[-1].text
    review_count_list.append(review_count)
    print(review_count)

    # product rating
    product_rating_sel = driver.find_element(By.CSS_SELECTOR, '.css-n209rx')

    # Get the value of the aria-label attribute
    product_rating = product_rating_sel.get_attribute("aria-label")

    product_rating_list.append(product_rating)

    # Extract the rating from the aria-label attribute
    print("Rating:", product_rating)


# creating a Dataframe from the dictonary
product_details = {
    "product_title": product_title_list,
    "product_category": product_category_list,
    "product_price": product_price_list,
    "product_description": product_description_list,
    "review_count": review_count_list,
    "product_rating": product_rating_list
}

df = pd.DataFrame(product_details)

print(df)


""" 
data cleaning using python library called re(regex) to remove the euro sign and other strings to convert the price into float and also extract the value of review_count from reviews
"""

# Extract numeric values from strings and convert to float
df['product_price'] = df['product_price'].str.extract(
    r'(\d+\.\d+)').astype(float)


# Extract numeric values from strings and replace non-matching rows with "Not Applicable"
df['review_count'] = df['review_count'].apply(lambda x: re.findall(
    r'\d+', x)[0] if re.findall(r'\d+', x) else "Not Applicable")


""" 
Sending the dataframe to a NoSQL Database called Mongodb

"""

try:
    # Connect to MongoDB
    client = MongoClient(
        mongo_url)
    db = client['nike_product_scraper']
    collection = db['nike_product_details']

    # Convert DataFrame to dictionary
    data = df.to_dict(orient='records')
    print(data)

    # Insert data into MongoDB collection
    collection.insert_many(data)

    print("Data inserted successfully into MongoDB")

except Exception as e:
    print("Error:", e)

finally:
    # Close connection
    client.close()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd

# %%
# creating a chrome webdriver to run automation
driver = webdriver.Chrome()
driver.get("https://www.nike.com/ie/w/mens-shoes-nik1zy7ok")

# %%
driver.get("https://www.nike.com/ie/w/mens-shoes-nik1zy7ok")

# %%
shoe_ele = driver.find_elements(
    By.CSS_SELECTOR, '[data-testid="product-card__link-overlay"]')

# %%
len(shoe_ele)
# Out:
# 24

# %%
all_shoe_links = []

for i in range(len(shoe_ele)):
    link = shoe_ele[i].get_attribute("href")
    print(link)
    all_shoe_links.append(link)
# Out:
# https://www.nike.com/ie/t/air-jordan-1-low-shoes-WgK3MP/553558-140
# https://www.nike.com/ie/t/dunk-low-retro-shoe-wwlDHh/DD1391-100
# https://www.nike.com/ie/t/air-jordan-1-low-se-shoes-8Npn8f/CZ8455-100
# https://www.nike.com/ie/t/air-max-90-shoes-56b7nN/FJ4218-001
# https://www.nike.com/ie/t/air-force-1-flyknit-2-shoes-L5q9GR/AV3042-100
# https://www.nike.com/ie/t/air-max-alpha-trainer-5-workout-shoes-rdbbk2/DM0829-010
# https://www.nike.com/ie/t/air-max-plus-shoes-1gMZsK/604133-050
# https://www.nike.com/ie/t/air-max-dn-shoes-rZwC5C/DV3337-003
# https://www.nike.com/ie/t/jordan-max-aura-5-shoes-xstMgH/DZ4353-001
# https://www.nike.com/ie/t/air-max-90-shoes-ggrFKJ/FB9658-400
# https://www.nike.com/ie/t/air-force-1-07-shoes-CFVMS0/CW2288-111
# https://www.nike.com/ie/t/air-max-pulse-shoes-tLDqhN/FN7459-400
# https://www.nike.com/ie/t/air-max-plus-iii-shoes-mJkmzK/CJ9684-002
# https://www.nike.com/ie/t/air-jordan-1-low-shoes-QnthX1/DC0774-101
# https://www.nike.com/ie/t/court-vision-low-shoes-qNJnrx/FD0320-133
# https://www.nike.com/ie/t/air-max-plus-utility-shoes-HkwSWp/FD0670-001
# https://www.nike.com/ie/t/air-max-terrascape-90-shoes-FFLPwr/DH2973-100
# https://www.nike.com/ie/t/quest-5-road-running-shoes-lf4MST/DD0204-001
# https://www.nike.com/ie/t/air-force-1-07-shoes-qcn0p9/FJ4146-100
# https://www.nike.com/ie/t/dunk-low-shoes-NDWvwq/FZ4624-001
# https://www.nike.com/ie/t/air-max-plus-shoes-RDsCLr/FN6949-400
# https://www.nike.com/ie/t/air-max-pulse-roam-shoes-SBmD6M/DZ3544-001
# https://www.nike.com/ie/t/air-max-270-shoes-Kqzbp7/AH8050-100
# https://www.nike.com/ie/t/sb-force-58-skate-shoes-3FxQvm/DV5477-003

# %%
driver.get(all_shoe_links[6])

# %%
# dictornary to store all product details
product_title_list = []
product_category_list = []
product_price_list = []
product_description_list = []
review_count_list = []
product_rating_list = []

for i in range(6, 7):
    # for i in range(len(all_shoe_links)):
    driver.get(all_shoe_links[i])
    time.sleep(3)

    # product title
    product_title = driver.find_elements(
        By.CSS_SELECTOR, '[data-test="product-title"]')[1].text
    product_title_list.append(product_title)
    print(product_title)

    # product category
    product_category = driver.find_elements(
        By.CSS_SELECTOR, '[data-test="product-sub-title"]')[1].text
    product_category_list.append(product_category)
    print(product_category)

    # product_price
    product_price = driver.find_elements(
        By.CSS_SELECTOR, '[data-test="product-price"]')[1].text
    product_price_list.append(product_price)
    print(product_price)

    # product_description
    product_description = driver.find_element(
        By.CSS_SELECTOR, '[class="description-preview body-2 css-1pbvugb"]').text
    product_description_list.append(product_description)
    print(product_description)

    # review_count
    review_count = driver.find_elements(
        By.CSS_SELECTOR, '[class="headline-4"]')[-1].text
    review_count_list.append(review_count)
    print(review_count)

    # product rating
    product_rating_sel = driver.find_element(By.CSS_SELECTOR, '.css-n209rx')

    # Get the value of the aria-label attribute
    product_rating = product_rating_sel.get_attribute("aria-label")

    product_rating_list.append(product_rating)

    # Extract the rating from the aria-label attribute
    print("Rating:", product_rating)
# Out:
# Nike Air Max Plus
# Men's Shoes
# €189.99
# Let your attitude have the edge in your Nike Air Max Plus, a Tuned Air experience that offers premium stability and unbelievable cushioning. Featuring the original's wavy design lines, TPU accents and airy mesh on the upper, it celebrates defiant style.
# Colour Shown: Black/Black/Black
# Style: 604133-050
# Reviews (361)
# Rating: 4.3

# %%
product_details = {
    "product_title": product_title_list,
    "product_category": product_category_list,
    "product_price": product_price_list,
    "product_description": product_description_list,
    "review_count": review_count_list,
    "product_rating": product_rating_list
}

df = pd.DataFrame(product_details)
# Out:
#                    product_title          product_category  \
# 0               Air Jordan 1 Low               Men's Shoes
# 1            Nike Dunk Low Retro                Men's Shoe
# 2            Air Jordan 1 Low SE               Men's Shoes
# 3                Nike Air Max 90               Men's Shoes
# 4   Nike Air Force 1 Flyknit 2.0                     Shoes
# 5   Nike Air Max Alpha Trainer 5       Men's Workout Shoes
# 6              Nike Air Max Plus               Men's Shoes
# 7                Nike Air Max Dn               Men's Shoes
# 8              Jordan Max Aura 5               Men's Shoes
# 9                Nike Air Max 90               Men's Shoes
# 10          Nike Air Force 1 '07               Men's Shoes
# 11            Nike Air Max Pulse               Men's Shoes
# 12         Nike Air Max Plus III               Men's Shoes
# 13              Air Jordan 1 Low             Women's Shoes
# 14         Nike Court Vision Low               Men's Shoes
# 15     Nike Air Max Plus Utility               Men's Shoes
# 16    Nike Air Max Terrascape 90               Men's Shoes
# 17                  Nike Quest 5  Men's Road Running Shoes
# 18          Nike Air Force 1 '07               Men's Shoes
# 19                 Nike Dunk Low               Men's Shoes
# 20             Nike Air Max Plus               Men's Shoes
# 21       Nike Air Max Pulse Roam               Men's Shoes
# 22              Nike Air Max 270               Men's Shoes
# 23              Nike SB Force 58               Skate Shoes
#
#                product_price  \
# 0                    €129.99
# 1                    €119.99
# 2                    €139.99
# 3                    €159.99
# 4                    €119.99
# 5                     €84.99
# 6                    €189.99
# 7                    €169.99
# 8   Discounted from\n€129.99
# 9                    €159.99
# 10                   €119.99
# 11  Discounted from\n€159.99
# 12                   €189.99
# 13                   €129.99
# 14                    €79.99
# 15                   €199.99
# 16  Discounted from\n€159.99
# 17   Discounted from\n€79.99
# 18                   €119.99
# 19                   €129.99
# 20                   €189.99
# 21  Discounted from\n€169.99
# 22                   €159.99
# 23                    €74.99
#
#                                   product_description  \
# 0   Inspired by the original that debuted in 1985,...
# 1   Created for the hardwood but taken to the stre...
# 2   Always fresh and never out of style, the Air J...
# 3   Nothing as fly, nothing as comfortable, nothin...
# 4   Inspired by the shoe that's been reigning the ...
# 5   Finish your last rep with power and rack it wi...
# 6   Let your attitude have the edge in your Nike A...
# 7   Say hello to the next generation of Air techno...
# 8   Whenyou need a shoe that's ready 24/7, it's go...
# 9   Lace up and feel the legacy in this champion r...
# 10  The radiance lives on in the Nike Air Force 1 ...
# 11  Mixing one part urban to one part tough, the A...
# 12  The Nike Air Max Plus III combines ultra-comfo...
# 13  Always in, always fresh. The Air Jordan 1 Low ...
# 14  In love with the look of old-school basketball...
# 15  Inspired by the beach but made for city street...
# 16  Consider for a moment that pause when you see ...
# 17  You lace up in pursuit of new personal goals. ...
# 18  Comfortable, durable and timeless—it's number ...
# 19  Show your love for the league in the classic l...
# 20  Let your attitude have the edge with flame-lik...
# 21  The Air Max Pulse Roam takes cues from its sty...
# 22  Nike's first lifestyle Air Max brings you styl...
# 23  The latest and greatest innovation to hit the ...
#
#                  review_count product_rating
# 0              Reviews (1058)            4.8
# 1               Reviews (956)            4.7
# 2                 Reviews (3)            4.3
# 3                 Reviews (8)              4
# 4                Reviews (19)            4.4
# 5               Reviews (219)            4.4
# 6   Free Delivery and Returns            4.3
# 7           How This Was Made            4.7
# 8   Free Delivery and Returns            4.6
# 9                Reviews (41)            4.9
# 10  Free Delivery and Returns            4.8
# 11  Free Delivery and Returns            4.3
# 12               Reviews (50)            4.6
# 13              Reviews (563)            4.8
# 14  Free Delivery and Returns            4.7
# 15  Free Delivery and Returns            4.6
# 16          How This Was Made            4.3
# 17               Reviews (48)            3.8
# 18               Reviews (17)            4.8
# 19               Reviews (26)            4.8
# 20                Reviews (2)              5
# 21               Reviews (31)            4.6
# 22  Free Delivery and Returns            4.5
# 23  Free Delivery and Returns            4.5

# %% [markdown]
# df

# %%
# cleaning up the dataframe
import re
# Extract numeric values from strings and convert to float
df['product_price'] = df['product_price'].str.extract(
    r'(\d+\.\d+)').astype(float)

# Now df['product_price'] contains only float values
print(df)
# Out:
#                    product_title          product_category  product_price  \
# 0               Air Jordan 1 Low               Men's Shoes         129.99
# 1            Nike Dunk Low Retro                Men's Shoe         119.99
# 2            Air Jordan 1 Low SE               Men's Shoes         139.99
# 3                Nike Air Max 90               Men's Shoes         159.99
# 4   Nike Air Force 1 Flyknit 2.0                     Shoes         119.99
# 5   Nike Air Max Alpha Trainer 5       Men's Workout Shoes          84.99
# 6              Nike Air Max Plus               Men's Shoes         189.99
# 7                Nike Air Max Dn               Men's Shoes         169.99
# 8              Jordan Max Aura 5               Men's Shoes         129.99
# 9                Nike Air Max 90               Men's Shoes         159.99
# 10          Nike Air Force 1 '07               Men's Shoes         119.99
# 11            Nike Air Max Pulse               Men's Shoes         159.99
# 12         Nike Air Max Plus III               Men's Shoes         189.99
# 13              Air Jordan 1 Low             Women's Shoes         129.99
# 14         Nike Court Vision Low               Men's Shoes          79.99
# 15     Nike Air Max Plus Utility               Men's Shoes         199.99
# 16    Nike Air Max Terrascape 90               Men's Shoes         159.99
# 17                  Nike Quest 5  Men's Road Running Shoes          79.99
# 18          Nike Air Force 1 '07               Men's Shoes         119.99
# 19                 Nike Dunk Low               Men's Shoes         129.99
# 20             Nike Air Max Plus               Men's Shoes         189.99
# 21       Nike Air Max Pulse Roam               Men's Shoes         169.99
# 22              Nike Air Max 270               Men's Shoes         159.99
# 23              Nike SB Force 58               Skate Shoes          74.99
#
#                                   product_description  \
# 0   Inspired by the original that debuted in 1985,...
# 1   Created for the hardwood but taken to the stre...
# 2   Always fresh and never out of style, the Air J...
# 3   Nothing as fly, nothing as comfortable, nothin...
# 4   Inspired by the shoe that's been reigning the ...
# 5   Finish your last rep with power and rack it wi...
# 6   Let your attitude have the edge in your Nike A...
# 7   Say hello to the next generation of Air techno...
# 8   Whenyou need a shoe that's ready 24/7, it's go...
# 9   Lace up and feel the legacy in this champion r...
# 10  The radiance lives on in the Nike Air Force 1 ...
# 11  Mixing one part urban to one part tough, the A...
# 12  The Nike Air Max Plus III combines ultra-comfo...
# 13  Always in, always fresh. The Air Jordan 1 Low ...
# 14  In love with the look of old-school basketball...
# 15  Inspired by the beach but made for city street...
# 16  Consider for a moment that pause when you see ...
# 17  You lace up in pursuit of new personal goals. ...
# 18  Comfortable, durable and timeless—it's number ...
# 19  Show your love for the league in the classic l...
# 20  Let your attitude have the edge with flame-lik...
# 21  The Air Max Pulse Roam takes cues from its sty...
# 22  Nike's first lifestyle Air Max brings you styl...
# 23  The latest and greatest innovation to hit the ...
#
#                  review_count product_rating
# 0              Reviews (1058)            4.8
# 1               Reviews (956)            4.7
# 2                 Reviews (3)            4.3
# 3                 Reviews (8)              4
# 4                Reviews (19)            4.4
# 5               Reviews (219)            4.4
# 6   Free Delivery and Returns            4.3
# 7           How This Was Made            4.7
# 8   Free Delivery and Returns            4.6
# 9                Reviews (41)            4.9
# 10  Free Delivery and Returns            4.8
# 11  Free Delivery and Returns            4.3
# 12               Reviews (50)            4.6
# 13              Reviews (563)            4.8
# 14  Free Delivery and Returns            4.7
# 15  Free Delivery and Returns            4.6
# 16          How This Was Made            4.3
# 17               Reviews (48)            3.8
# 18               Reviews (17)            4.8
# 19               Reviews (26)            4.8
# 20                Reviews (2)              5
# 21               Reviews (31)            4.6
# 22  Free Delivery and Returns            4.5
# 23  Free Delivery and Returns            4.5

# %%
# Extract numeric values from strings and replace non-matching rows with "Not Applicable"
df['review_count'] = df['review_count'].apply(lambda x: re.findall(
    r'\d+', x)[0] if re.findall(r'\d+', x) else "Not Applicable")

# %%
df
# Out:
#                    product_title          product_category  product_price  \
# 0               Air Jordan 1 Low               Men's Shoes         129.99
# 1            Nike Dunk Low Retro                Men's Shoe         119.99
# 2            Air Jordan 1 Low SE               Men's Shoes         139.99
# 3                Nike Air Max 90               Men's Shoes         159.99
# 4   Nike Air Force 1 Flyknit 2.0                     Shoes         119.99
# 5   Nike Air Max Alpha Trainer 5       Men's Workout Shoes          84.99
# 6              Nike Air Max Plus               Men's Shoes         189.99
# 7                Nike Air Max Dn               Men's Shoes         169.99
# 8              Jordan Max Aura 5               Men's Shoes         129.99
# 9                Nike Air Max 90               Men's Shoes         159.99
# 10          Nike Air Force 1 '07               Men's Shoes         119.99
# 11            Nike Air Max Pulse               Men's Shoes         159.99
# 12         Nike Air Max Plus III               Men's Shoes         189.99
# 13              Air Jordan 1 Low             Women's Shoes         129.99
# 14         Nike Court Vision Low               Men's Shoes          79.99
# 15     Nike Air Max Plus Utility               Men's Shoes         199.99
# 16    Nike Air Max Terrascape 90               Men's Shoes         159.99
# 17                  Nike Quest 5  Men's Road Running Shoes          79.99
# 18          Nike Air Force 1 '07               Men's Shoes         119.99
# 19                 Nike Dunk Low               Men's Shoes         129.99
# 20             Nike Air Max Plus               Men's Shoes         189.99
# 21       Nike Air Max Pulse Roam               Men's Shoes         169.99
# 22              Nike Air Max 270               Men's Shoes         159.99
# 23              Nike SB Force 58               Skate Shoes          74.99
#
#                                   product_description    review_count  \
# 0   Inspired by the original that debuted in 1985,...            1058
# 1   Created for the hardwood but taken to the stre...             956
# 2   Always fresh and never out of style, the Air J...               3
# 3   Nothing as fly, nothing as comfortable, nothin...               8
# 4   Inspired by the shoe that's been reigning the ...              19
# 5   Finish your last rep with power and rack it wi...             219
# 6   Let your attitude have the edge in your Nike A...  Not Applicable
# 7   Say hello to the next generation of Air techno...  Not Applicable
# 8   Whenyou need a shoe that's ready 24/7, it's go...  Not Applicable
# 9   Lace up and feel the legacy in this champion r...              41
# 10  The radiance lives on in the Nike Air Force 1 ...  Not Applicable
# 11  Mixing one part urban to one part tough, the A...  Not Applicable
# 12  The Nike Air Max Plus III combines ultra-comfo...              50
# 13  Always in, always fresh. The Air Jordan 1 Low ...             563
# 14  In love with the look of old-school basketball...  Not Applicable
# 15  Inspired by the beach but made for city street...  Not Applicable
# 16  Consider for a moment that pause when you see ...  Not Applicable
# 17  You lace up in pursuit of new personal goals. ...              48
# 18  Comfortable, durable and timeless—it's number ...              17
# 19  Show your love for the league in the classic l...              26
# 20  Let your attitude have the edge with flame-lik...               2
# 21  The Air Max Pulse Roam takes cues from its sty...              31
# 22  Nike's first lifestyle Air Max brings you styl...  Not Applicable
# 23  The latest and greatest innovation to hit the ...  Not Applicable
#
#    product_rating
# 0             4.8
# 1             4.7
# 2             4.3
# 3               4
# 4             4.4
# 5             4.4
# 6             4.3
# 7             4.7
# 8             4.6
# 9             4.9
# 10            4.8
# 11            4.3
# 12            4.6
# 13            4.8
# 14            4.7
# 15            4.6
# 16            4.3
# 17            3.8
# 18            4.8
# 19            4.8
# 20              5
# 21            4.6
# 22            4.5
# 23            4.5

# %%
mongodb+srv://sohailansari1969:Liahos15%40@nikeproductscraper.aph6abq.mongodb.net/
# Out:
# Reviews (1058)

# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pymongo
#   Downloading pymongo-4.6.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (676 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 676.9/676.9 KB 1.2 MB/s eta 0:00:00a 0:00:01
# Collecting dnspython<3.0.0,>=1.16.0
#   Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 KB 1.4 MB/s eta 0:00:0000:0100:01
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.6.1 pymongo-4.6.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from pymongo import MongoClient

try:
    # Connect to MongoDB
    client = MongoClient(
        mongo_url)
    db = client['nike_product_scraper']
    collection = db['nike_product_details']

    # Convert DataFrame to dictionary
    data = df.to_dict(orient='records')
    print(data)

    # Insert data into MongoDB collection
    collection.insert_many(data)

    print("Data inserted successfully into MongoDB")

except Exception as e:
    print("Error:", e)

finally:
    # Close connection
    client.close()
# Out:
# [{'product_title': 'Air Jordan 1 Low', 'product_category': "Men's Shoes", 'product_price': '€129.99', 'product_description': "Inspired by the original that debuted in 1985, the Air Jordan 1 Low offers a clean, classic look that's familiar yet always fresh. With an iconic design that pairs perfectly with any 'fit, these kicks ensure you'll always be on point.\nColour Shown: White/Black/White/Royal Blue\nStyle: 553558-140", 'review_count': 'Reviews (1058)', 'product_rating': '4.8'}, {'product_title': 'Nike Dunk Low Retro', 'product_category': "Men's Shoe", 'product_price': '€119.99', 'product_description': "Created for the hardwood but taken to the streets, the Nike Dunk Low Retro returns with crisp overlays and original team colours. This basketball icon channels '80s vibes with premium leather in the upper that looks good and breaks in even better. Modern footwear technology helps bring the comfort into the 21st century.\nColour Shown: White/White/Black\nStyle: DD1391-100", 'review_count': 'Reviews (956)', 'product_rating': '4.7'}, {'product_title': 'Air Jordan 1 Low SE', 'product_category': "Men's Shoes", 'product_price': '€139.99', 'product_description': 'Always fresh and never out of style, the Air Jordan 1 Low is one of the most iconic sneakers of all time.This SE version shakes up the classic design with flavourful new colour schemes and trim details.\nColour Shown: White/Midnight Navy/White\nStyle: CZ8455-100', 'review_count': 'Reviews (3)', 'product_rating': '4.3'}, {'product_title': 'Nike Air Max 90', 'product_category': "Men's Shoes", 'product_price': '€159.99', 'product_description': 'Nothing as fly, nothing as comfortable, nothing as proven. The Nike Air Max 90 stays true to its OG running roots with the iconic Waffle sole, stitched overlays and classic TPU details. Classic colours celebrate your fresh look while Max Air cushioning adds comfort to the journey.\nColour Shown: Black/University Blue\nStyle: FJ4218-001', 'review_count': 'Reviews (8)', 'product_rating': '4'}, {'product_title': 'Nike Air Force 1 Flyknit 2.0', 'product_category': 'Shoes', 'product_price': '€119.99', 'product_description': "Inspired by the shoe that's been reigning the courts since 1982, the Nike Air Force 1 Flyknit 2.0 brings back the AF-1 in a lighter-than-ever design.Rocking Flyknit construction with classic AF-1 design lines, it serves up old-school hoops vibes with a featherweight feel.\nColour Shown: White/Pure Platinum/White/Pure Platinum\nStyle: AV3042-100", 'review_count': 'Reviews (19)', 'product_rating': '4.4'}, {'product_title': 'Nike Air Max Alpha Trainer 5', 'product_category': "Men's Workout Shoes", 'product_price': '€84.99', 'product_description': "Finish your last rep with power and rack it with a roar that stuns the gym floor in the Nike Air Max Alpha Trainer 5. The Max Air cushioning offers comfortable stability for lifting whether it's a light or heavy day. A wide, flat base gives you enhanced stability and grip for all kinds of tough workouts without sacrificing style, as you roam from station to station and set to set.\nColour Shown: Black/Black/Dark Smoke Grey\nStyle: DM0829-010", 'review_count': 'Reviews (219)', 'product_rating': '4.4'}, {'product_title': 'Nike Air Max Plus', 'product_category': "Men's Shoes", 'product_price': '€189.99', 'product_description': "Let your attitude have the edge in your Nike Air Max Plus, a Tuned Air experience that offers premium stability and unbelievable cushioning. Featuring the original's wavy design lines, TPU accents and airy mesh on the upper, it celebrates defiant style.\nColour Shown: Black/Black/Black\nStyle: 604133-050", 'review_count': 'Free Delivery and Returns', 'product_rating': '4.3'}, {'product_title': 'Nike Air Max Dn', 'product_category': "Men's Shoes", 'product_price': '€169.99', 'product_description': "Say hello to the next generation of Air technology. The Air Max Dn features our Dynamic Air unit system of dual-pressure tubes, creating a reactive sensation with ev ...
# Data inserted successfully into MongoDB
